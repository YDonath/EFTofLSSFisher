# %%
from resultsfuncs import *

# %%
Prioramb=mmread("../Fishersn2/Prioramb.mtx")

# %% [markdown]
# ### BOSS imports

# %% [markdown]
# Full P results w/o 4 sky correlation

# %%
Pfull4sky = mmread('../Fishersn2/BOSS/Pfull4sky.mtx')
Pfullnoskycorr = mmread('../Fishersn2/BOSS/Pfullnoskycorr.mtx')

# %% [markdown]
# Full PB cross w/o 4 sky correlation

# %%
PBcross4sky = mmread('../Fishersn2/BOSS/PBcross4sky.mtx')
PBcrossnoskycorr = mmread('../Fishersn2/BOSS/PBcrossnoskycorr.mtx')

# %% [markdown]
# Numerical covariance Diagonals  w/o 4 sky correlation,  w/o B

# %%
PNumD4sky = mmread('../Fishersn2/BOSS/PNumD4sky.mtx')
PNumDnoskycorr = mmread('../Fishersn2/BOSS/PNumDnoskycorr.mtx')
PBNumD4sky = mmread('../Fishersn2/BOSS/PBNumD4sky.mtx')
PBNumDnoskycorr = mmread('../Fishersn2/BOSS/PBNumDnoskycorr.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
Panafullz = mmread('../Fishersn2/BOSS/Panafullz.mtx')
PBanafullz = mmread('../Fishersn2/BOSS/PBanafullz.mtx')

PanafullznoAP = mmread('../Fishersn2/BOSS/PanafullznoAP.mtx')
PBanafullznoAP = mmread('../Fishersn2/BOSS/PBanafullznoAP.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B no shot noise (full mu)

# %%
PanamufullzNS = mmread('../Fishersn2/BOSS/PanamufullzNS.mtx')
PBanamufullzNS = mmread('../Fishersn2/BOSS/PBanamufullzNS.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence full mu dependence,  w/o B

# %%
Panamufullz = mmread('../Fishersn2/BOSS/Panamufullz.mtx')
PBanamufullz = mmread('../Fishersn2/BOSS/PBanamufullz.mtx')

# %% [markdown]
# Analytical covariance BTree

# %%
PBanamufullzT = mmread('../Fishersn2/BOSS/PBanamufullzT.mtx')

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
Pstrong = mmread('../Fishersn2/BOSS/Ppertprior.mtx')
PBstrong = mmread('../Fishersn2/BOSS/PBpertprior.mtx')

# %% [markdown]
# ### DESI Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
DPanafullz = mmread('../Fishersn2/DESI/Panafullz.mtx').real
DPBanafullz = mmread('../Fishersn2/DESI/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
DPanamufullz = mmread('../Fishersn2/DESI/Panamufullz.mtx').real
DPBanamufullz = mmread('../Fishersn2/DESI/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, 2loop,  w/o B

# %%
DPanamufullz2L = mmread('../Fishersn2/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('../Fishersn2/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B

# %%
DPBanamufullzT = mmread('../Fishersn2/DESI/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, NS,  w/o B

# %%
DPanamufullzNS = mmread('../Fishersn2/DESI/PanamufullzNS.mtx').real
DPBanamufullzNS = mmread('../Fishersn2/DESI/PBanamufullzNS.mtx').real

# %%
DPanamufullz2L = mmread('../Fishersn2/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('../Fishersn2/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
DPstrong = mmread('../Fishersn2/DESI/Ppertprior.mtx')
DPBstrong = mmread('../Fishersn2/DESI/PBpertprior.mtx')

# %% [markdown]
# ### MegaMapper -optimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMoPanafullz = mmread('../Fishersn2/MMo/Panafullz.mtx').real
MMoPBanafullz = mmread('../Fishersn2/MMo/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMoPanamufullz = mmread('../Fishersn2/MMo/Panamufullz.mtx').real
MMoPBanamufullz = mmread('../Fishersn2/MMo/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMoPBanamufullzT = mmread('../Fishersn2/MMo/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMoPanamufullzNS = mmread('../Fishersn2/MMo/PanamufullzNS.mtx').real
MMoPBanamufullzNS = mmread('../Fishersn2/MMo/PBanamufullzNS.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
MMoPstrong = mmread('../Fishersn2/MMo/Ppertprior.mtx')
MMoPBstrong = mmread('../Fishersn2/MMo/PBpertprior.mtx')

# %%
MMoPanamufullz2L = mmread('../Fishersn2/MMo/Panamufullz2L.mtx').real
MMoPBanamufullz2L = mmread('../Fishersn2/MMo/PBanamufullz2L.mtx').real

# %% [markdown]
# ### MegaMapper -pessimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMpPanafullz = mmread('../Fishersn2/MMp/Panafullz.mtx').real
MMpPBanafullz = mmread('../Fishersn2/MMp/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMpPanamufullz = mmread('../Fishersn2/MMp/Panamufullz.mtx').real
MMpPBanamufullz = mmread('../Fishersn2/MMp/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMpPBanamufullzT = mmread('../Fishersn2/MMp/PBanamufullzT.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
MMpPstrong = mmread('../Fishersn2/MMp/Ppertprior.mtx')
MMpPBstrong = mmread('../Fishersn2/MMp/PBpertprior.mtx')

# %%
MMpPanamufullz2L = mmread('../Fishersn2/MMp/Panamufullz2L.mtx').real
MMpPBanamufullz2L = mmread('../Fishersn2/MMp/PBanamufullz2L.mtx').real

# %% [markdown]
# ## BOSS Pipeline validation

# %% [markdown]
# Reduction to Diagonal Covariance and fits

# %%
getPlot([Pfull4sky,PNumDnoskycorr,Panafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P measured Covariance","P NumD","P Analytical"])
getPlot([PBcross4sky,PBNumDnoskycorr,PBanafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["$P_\ell+B_0$ measured Cov.","$P_\ell+B_0$ measured diagonal Cov.","$P_\ell+B_0$ analytical diagonal Cov."],'plotsn2/BOSS/PB_Diagvalidation')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [41.781239755178255, 29.327467034059797, 27.924580221990126]
# [357.02468647935353, 314.049918131981, 274.5081001160121]
# [100.3991136267302, 111.16172027515522, 94.55827556760183]

# %% [markdown]
# ## BOSS Results

# %% [markdown]
# ### Additional Parameters, with full numerical covariances

# %%
getPlot([Pfullnoskycorr,PBcrossnoskycorr],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["$P_\ell$","$P_\ell+B_0$"],'plotsn2/BOSS/PBNum_extrans',18,13,17)
getPlot([Pfullnoskycorr,PBcrossnoskycorr],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["$P_\ell$","$P_\ell+B_0$"],'plotsn2/BOSS/PBNum_extramn',15,12,15,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.08941232068215355, 0.8444940387591933], [-0.08034095186936346, 0.40867162710772625]]

# %%
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# [35.781916172449186, 26.678295942902956, 25.207536762137476]
# [245.20866202094174, 300.52816478624123, 265.69366533268584]
# [93.61151366077878, 111.14961672913454, 94.38745254460497]

# %%
getPlot([Panafullz,Panamufullz],["lnAs", "h", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om"],["$P_0+P_2$","$P^r$ full"])
# Out:
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Impact of higher multipoles and shot noise (with analytical covariance)

# %%
fnlerrors([PBanafullznoAP,PBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanafullznoAP ,PBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanafullznoAP,PBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# [25.207536762146265, 23.01438488309409]
# [265.693665332619, 252.7372410358431]
# [94.38745254457704, 67.09341816962367]

# %%
getPlot([PanafullznoAP,Panamufullz,PBanafullznoAP,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["$P_0+P_2$","$P^r$ full","$P_0+P_2+B_0$","$P^r+B^r$ full"],'plotsn2/BOSS/highermulti',15,12,15)
getPlot([Panamufullz,PanamufullzNS,PBanamufullz,PBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsn2/BOSS/shotnoise',15,12,15)
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [25.207536762137476, 23.01438488309409, 11.164539947248581]
# [265.69366533268584, 252.7372410358431, 147.35572830135362]
# [94.38745254460497, 67.09341816962367, 40.688692498899755]

# %%
samp1,cpar1,lb1 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([Panamufullz,PBanamufullz,Panamufullz+Prioramb,PBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free","P: bias free + g.p.","P+B: bias free + g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotsn2/BOSS/biasfixns',15,12,15)

fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([PBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [23.01438488309409, 19.30700081133056]
# [252.7372410358431, 187.21646766269268]
# [67.09341816962367, 51.42096414236866]
# [4.779712287194547]
# [45.49163329498812]
# [26.295086635523607]

# %%
printerr(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))

printerr(getError([Panamufullz+Prioramb,PBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))

printerr(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.01395  0.161    0.01242  0.06747 ]
#  [0.006669 0.05451  0.005714 0.0253  ]]
# Removed no burn in
# Removed no burn in
# [[0.01308  0.1317   0.0107   0.04709 ]
#  [0.006503 0.04312  0.004881 0.01918 ]]
# Removed no burn in
# Removed no burn in
# [[0.0122   0.05646  0.007778 0.02606 ]
#  [0.00536  0.01916  0.003518 0.007465]]

# %%
printerr(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob","Ok"]+biasindex,[ "h", "lnAs","Om","ns","Ok"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.01449  0.7375   0.01282  0.07531  0.2901  ]
#  [0.006687 0.1644   0.005829 0.02681  0.06383 ]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plotsn2/BOSS/fnlwithbiasT',15,12,15)

fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [37.40697165467831, 23.01438488309409, 18.159845126190604, 16.732332234995592]
# [357.1956966069592, 252.7372410358431, 163.97626537323885, 137.5114243275499]
# [142.16733084388113, 67.09341816962367, 55.71930680005882, 46.57057512834543]

# %% [markdown]
# ## DESI Results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","logmn", "ob"],[ "h", "lnAs","Om","logmn"],["P","P +B"],'plotsn2/DESI/PB_extramnfix',15,12,15,1)
# Out:
# Removed no burn in
# Removed no burn in
# [[-0.05963731313118012, 0.14775357578399922], [-0.032225839710773016, 0.04754885869961188]]

# %%
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["P","P +B"],'plotsn2/DESI/PB_extrans',18,13,17)
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plotsn2/DESI/PB_extramn',15,12,15,1)
fnlerrors([DPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.0724009443300388, 0.262331237691005], [-0.0465507651807442, 0.08709341740468408]]
# [3.456694796994808]
# [114.25109544173044]
# [30.187470134808535]

# %% [markdown]
# ### Shotnoise and bias impact

# %%
getPlot([DPanamufullz,DPanamufullzNS,DPBanamufullz,DPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsn2/DESI/shotnoise',15,12,15)
fnlerrors([DPBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [1.6717581220785622]
# [67.32399783409096]
# [17.294727879207922]

# %%
samp1,cpar1,lb1 = getSamps([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([DPanamufullz,DPBanamufullz,DPanamufullz+Prioramb,DPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free","P: bias free + g.p.","P+B: bias free + g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotsn2/DESI/biasfixns',15,12,15)

fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.456694796994808, 3.3551337341965097]
# [114.25109544173044, 83.3985632930665]
# [30.187470134808535, 22.931829960285633]
# [1.988483619288975]
# [20.73871273887992]
# [11.05455275135834]

# %%
printerr(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([DPanamufullz+Prioramb,DPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.005742 0.0355   0.00409  0.01879 ]
#  [0.00424  0.01952  0.00221  0.01049 ]]
# Removed no burn in
# Removed no burn in
# [[0.005648 0.03216  0.004049 0.01555 ]
#  [0.004194 0.01763  0.002156 0.009034]]
# Removed no burn in
# Removed no burn in
# [[0.005314 0.0213   0.003211 0.01084 ]
#  [0.003726 0.01045  0.001583 0.004074]]

# %% [markdown]
# ### 2 Loop P impact

# %%
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om" ,"ob"]+biasindexstfix,[ "h", "lnAs","Om"],["P +B","P 2L +B"],'plotsn2/DESI/PB_2L',15,12,15)
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "lnAs", "h", "Om","ns","Ok"],["P +B","P 2L +B"],'plotsn2/DESI/PB_2L',15,12,15)

fnlerrors([DPBanamufullz2L],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz2L],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz2L],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.4227338386477397]
# [111.8765876911343]
# [30.11726636905527]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([DPBanamufullzT,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plotsn2/DESI/PB_extrans_Tree',15,12,15)
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.6094664022749523, 3.456694796994808]
# [141.67776536199747, 114.25109544173044]
# [71.54468968139815, 30.187470134808535]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plotsn2/DESI/fnlwithbiasT',15,12,15)

fnlfnlerrors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
errors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.6094664022749523, 3.456694796994808, 3.3096354865126774, 3.2355410971930865]
# [141.67776536199747, 114.25109544173044, 73.92948127010736, 60.82218283973264]
# [71.54468968139815, 30.187470134808535, 28.204432822228657, 22.127767330329515]

# %%
getPlot([DPBanamufullz,DPBanamufullz+DPBstrong],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],['$P+B$','$P+B+pert. Prior$'],'plotsn2/DESI/PB_extrans_prior',18,13,17)
getPlot([DPBanamufullz,DPBanamufullz+DPBstrong],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$'],'plotsn2/DESI/PB_extramn_prior',18,13,17,1)
getPlot([DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior + g.p.$'],'plotsn2/DESI/PB_extramn_prior2',18,13,17,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.0465507651807442, 0.08709341740468408], [-0.045480362911269445, 0.08342014976594632]]
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.0465507651807442, 0.08709341740468408], [-0.045480362911269445, 0.08342014976594632], [-0.0441076231227688, 0.07891527536868244]]

# %% [markdown]
# ## MegaMapper optimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMoPanamufullz,MMoPanamufullz2L],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P","P 2L"],'plotsn2/MMo/PB_extrans2L',18,13,17)
getPlot([MMoPBanamufullz,MMoPBanamufullz2L],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P +B","P +B 2L"],'plotsn2/MMo/PB_extrans2L',18,13,17)
fnlerrors([MMoPBanamufullz,MMoPBanamufullz2L],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz2L],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz2L],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2713882112022941, 0.26905445898565467]
# [18.02015961686584, 17.077495802733356]
# [5.143861140265171, 4.884709302654753]

# %%
getPlot([MMpPanamufullz,MMpPanamufullz2L],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P","P 2L"],'plotsn2/MMp/PB_extrans2L',18,13,17)
getPlot([MMpPBanamufullz,MMpPBanamufullz2L],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P +B","P +B 2L"],'plotsn2/MMp/PB_extrans2L',18,13,17)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P","P +B"],'plotsn2/MMo/PB_extrans',18,13,17)
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plotsn2/MMo/PB_extramn',15,12,15,1)
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.031474173327359634, 0.04593038107765875], [-0.0073640641875816065, 0.007949468122709247]]
# [0.2713882112022941]
# [18.02015961686584]
# [5.143861140265171]

# %%
getPlot([MMoPanamufullz,MMpPanamufullz],["Ok"],[ "Ok"],["P","P +B"],'plots_play/MMo/PB_extrans',18,13,17)
getPlot([MMoPanamufullz,MMpPanamufullz],["ns"],[ "ns"],["P","P +B"],'plots_play/MMo/PB_extrans',18,13,17)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Shot Noise impact and bias impact

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsn2/MMo/shotnoise',15,12,15)
fnlerrors([MMoPBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.11275841301197695]
# [5.405731342622181]
# [1.5027002210697218]

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob","Ok"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsn2/MMo/shotnoise',15,12,15)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
samp1,cpar1,lb1 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMoPanamufullz,MMoPBanamufullz,MMoPanamufullz+Prioramb,MMoPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free","P: bias free + g.p.","P+B: bias free + g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotsn2/MMo/biasfixns',15,12,15)


fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2713882112022941, 0.2653744276835785]
# [18.02015961686584, 14.163408987094606]
# [5.143861140265171, 4.098618139491307]
# [0.17076807326494978]
# [3.6136185197839032]
# [1.739279144572206]

# %%
printerr(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([MMoPanamufullz+Prioramb,MMoPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.003598  0.0132    0.001161  0.005029 ]
#  [0.002067  0.005156  0.0003459 0.001777 ]]
# Removed no burn in
# Removed no burn in
# [[0.00344   0.01066   0.001097  0.004253 ]
#  [0.00198   0.00473   0.0003249 0.001632 ]]
# Removed no burn in
# Removed no burn in
# [[0.002857  0.007363  0.0007855 0.002442 ]
#  [0.001593  0.0033    0.0001917 0.0008999]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plotsn2/MMo/fnlwithbiasT',15,12,15)

fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2859617706366799, 0.2713882112022941, 0.26615942059406805, 0.26119184685440683]
# [23.405074574321276, 18.02015961686584, 13.102148053653329, 10.75762904536315]
# [8.68922563072317, 5.143861140265171, 4.284770873171938, 3.654009363291735]

# %% [markdown]
# ## MegaMapper pesimistic results
#
# ### Base Results (All multipoles)

# %%
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","Ok","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["P","P +B"],'plotsn2/MMp/PB_extrans',18,13,17)
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plotsn2/MMp/PB_extramn',15,12,15,1)

fnlerrors([MMpPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.04557996290075706, 0.08375584679891947], [-0.013116844386455426, 0.015097108632654899]]
# [0.43943349605121074]
# [33.63871836035001]
# [9.870525444885258]

# %% [markdown]
# ### Perturbative prior

# %%
getPlot([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plotsn2/MMp/fnlwithbiasT',15,12,15)

fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.4513428709581922, 0.43943349605121074, 0.435358987646589, 0.42705694146393175]
# [40.80626736601931, 33.63871836035001, 23.115143426547238, 18.91691474329558]
# [18.077313139655345, 9.870525444885258, 8.20266605341455, 6.659894480663829]

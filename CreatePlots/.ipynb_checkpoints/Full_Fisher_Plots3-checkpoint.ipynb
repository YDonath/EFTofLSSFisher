# %%
from resultsfuncs import *

# %% [markdown]
# # Imports

# %% [markdown]
# ### BOSS imports

# %% [markdown]
# Full P results w/o 4 sky correlation

# %%
Pfull4sky = mmread('../Fisher3/BOSS/Pfull4sky.mtx')
Pfullnoskycorr = mmread('../Fisher3/BOSS/Pfullnoskycorr.mtx')

# %% [markdown]
# Full PB cross w/o 4 sky correlation

# %%
PBcross4sky = mmread('../Fisher3/BOSS/PBcross4sky.mtx')
PBcrossnoskycorr = mmread('../Fisher3/BOSS/PBcrossnoskycorr.mtx')

# %% [markdown]
# Numerical covariance Diagonals  w/o 4 sky correlation,  w/o B

# %%
PNumD4sky = mmread('../Fisher3/BOSS/PNumD4sky.mtx')
PNumDnoskycorr = mmread('../Fisher3/BOSS/PNumDnoskycorr.mtx')
PBNumD4sky = mmread('../Fisher3/BOSS/PBNumD4sky.mtx')
PBNumDnoskycorr = mmread('../Fisher3/BOSS/PBNumDnoskycorr.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
Panafullz = mmread('../Fisher3/BOSS/Panafullz.mtx')
PBanafullz = mmread('../Fisher3/BOSS/PBanafullz.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B no shot noise (full mu)

# %%
PanamufullzNS = mmread('../Fisher3/BOSS/PanamufullzNS.mtx')
PBanamufullzNS = mmread('../Fisher3/BOSS/PBanamufullzNS.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence full mu dependence,  w/o B

# %%
Panamufullz = mmread('../Fisher3/BOSS/Panamufullz.mtx')
PBanamufullz = mmread('../Fisher3/BOSS/PBanamufullz.mtx')

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
Pstrong = mmread('../Prior0/BOSS/Pstrong.mtx')
PBstrong = mmread('../Prior0/BOSS/PBStrong.mtx')

# %% [markdown]
# ### DESI Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
DPanafullz = mmread('../Fisher3/DESI/Panafullz.mtx').real
DPBanafullz = mmread('../Fisher3/DESI/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
DPanamufullz = mmread('../Fisher3/DESI/Panamufullz.mtx').real
DPBanamufullz = mmread('../Fisher3/DESI/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, 2loop,  w/o B

# %%
DPanamufullz2L = mmread('../Fisher3/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('../Fisher3/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B

# %%
DPBanamufullzT = mmread('../Fisher3/DESI/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, NS,  w/o B

# %%
DPanamufullzNS = mmread('../Fisher3/DESI/PanamufullzNS.mtx').real
DPBanamufullzNS = mmread('../Fisher3/DESI/PBanamufullzNS.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
DPstrong = mmread('../Prior0/DESI/Pstrong.mtx')
DPBstrong = mmread('../Prior0/DESI/PBStrong.mtx')

# %% [markdown]
# ### MegaMapper -optimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMoPanafullz = mmread('../Fisher3/MMo/Panafullz.mtx').real
MMoPBanafullz = mmread('../Fisher3/MMo/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMoPanamufullz = mmread('../Fisher3/MMo/Panamufullz.mtx').real
MMoPBanamufullz = mmread('../Fisher3/MMo/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMoPBanamufullzT = mmread('../Fisher3/MMo/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMoPanamufullzNS = mmread('../Fisher3/MMo/PanamufullzNS.mtx').real
MMoPBanamufullzNS = mmread('../Fisher3/MMo/PBanamufullzNS.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
MMoPstrong = mmread('../Prior0/DESI/Pstrong.mtx')
MMoPBstrong = mmread('../Prior0/DESI/PBStrong.mtx')

# %% [markdown]
# ### MegaMapper -pessimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMpPanafullz = mmread('../Fisher2/MMp/Panafullz.mtx').real
MMpPBanafullz = mmread('../Fisher2/MMp/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMpPanamufullz = mmread('../Fisher2/MMp/Panamufullz.mtx').real
MMpPBanamufullz = mmread('../Fisher2/MMp/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMpPBanamufullzT = mmread('../Fisher2/MMp/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMpPanamufullzNS = mmread('../Fisher2/MMp/PanamufullzNS.mtx').real
MMpPBanamufullzNS = mmread('../Fisher2/MMp/PBanamufullzNS.mtx').real

# %% [markdown]
# ## BOSS Pipeline validation

# %% [markdown]
# Reduction to Diagonal Covariance and fits

# %%
getPlot([Pfull4sky,PNumDnoskycorr,Panafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P measured Covariance","P NumD","P Analytical"])
getPlot([PBcross4sky,PBNumDnoskycorr,PBanafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P+B measured Cov.","P+B measured Cov.diag. ","P+B analytical Cov.diag."],'plotwp/BOSS/PB_Diagvalidation')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# # Results

# %% [markdown]
# ## BOSS Results

# %% [markdown]
# ### Additional Parameters, with full numerical covariances

# %%
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plotwp/BOSS/test')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plotwp/BOSS/PBNum_extrans')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plotwp/BOSS/PBNum_extramn')
getPlot([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plotwp/BOSS/PBNum_extraOk')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Impact of higher multipoles and shot noise (with analytical covariance)

# %%
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [28.0117601125072, 25.296974723359362, 11.972191785098584]
# [272.28778616175236, 258.84622360098683, 149.5260626154828]
# [94.69753291937023, 67.01295784946839, 39.08633412737525]

# %%
getPlot([Panafullz,Panamufullz,PBanafullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["$P_0+P_2$","$P^r$ full","$P_0+P_2+B_0$","$P^r+B^r$ full"],'plotwp/BOSS/highermulti')
getPlot([Panamufullz,PanamufullzNS,PBanamufullz,PBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotwp/BOSS/shotnoise')
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [28.0117601125072, 25.296974723359362, 11.972191785098584]
# [272.28778616175236, 258.84622360098683, 149.5260626154828]
# [94.69753291937023, 67.01295784946839, 39.08633412737525]

# %%
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [28.0117601125072, 25.296974723359362, 11.972191785098584]
# [272.28778616175236, 258.84622360098683, 149.5260626154828]
# [94.69753291937023, 67.01295784946839, 39.08633412737525]

# %%
fnlerrors([PBanafullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"],[ "fNLorth"])
# Out:
# [4.635528666426323]
# [44.99039793043523]
# [25.344159475745098]

# %%
fnlerrors([PBanafullz],["fNLloc"]+biasindex2,[ "fNLloc"])
fnlerrors([PBanafullz],["fNLeq"]+biasindex2,[ "fNLeq"])
fnlerrors([PBanafullz],["fNLorth"]+biasindex2,[ "fNLorth"])
# Out:
# [25.16992703908902]
# [263.8828047678985]
# [94.64877032005352]

# %%
samp1,cpar1,lb1 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotwp/BOSS/biasfixns')

fnlerrors([PBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [4.7812050184268795]
# [46.140352044780734]
# [26.615096608294632]

# %%
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.012507788344752763, 0.06164149174424525, 0.008073315413680901, 0.028338408383295044], [0.00534681094521091, 0.02039094557053596, 0.0037298312717322585, 0.008017889529610807]]
# Removed no burn in
# Removed no burn in
# [[0.014578157703766739, 0.16854415441677592, 0.01280104565690944, 0.07391191075107438], [0.006825043458115415, 0.05771898582013362, 0.005926859728665967, 0.02833021369965018]]

# %%
print(getError([Panafullz,PBanafullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
print(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.014632679538763302, 0.1688213010232993, 0.012763055331105387, 0.07302444873104826], [0.0068024866053157836, 0.0968843085617264, 0.0061201294907059015, 0.03266204435282468]]
# Removed no burn in
# Removed no burn in
# [[0.014578157703766739, 0.16854415441677592, 0.01280104565690944, 0.07391191075107438], [0.006825043458115415, 0.05771898582013362, 0.005926859728665967, 0.02833021369965018]]

# %%
print(getError([Pfull4sky,PBcross4sky],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
print(getError([Pfullnoskycorr,PBcrossnoskycorr],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.01702046515699087, 0.21433465471831753, 0.014857060150872623, 0.10322882070436067], [0.012945417423547228, 0.1483772170781167, 0.010834513537424033, 0.05975771477072076]]
# Removed no burn in
# Removed no burn in
# [[0.01428266697136545, 0.17419952016922202, 0.012405086902567045, 0.07349306856586463], [0.01116750894027182, 0.12119435624352382, 0.009414750211103383, 0.04316738352868948]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([Panamufullz,Panamufullz+Pstrong,PBanamufullz,PBanamufullz+PBstrong],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P+Prior","P+B","P+B+Prior"],'plotwp/BOSS/Priors')

fnlerrors([PBanamufullz,PBanamufullz+PBstrong],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBanamufullz,PBanamufullz+PBstrong],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBanamufullz,PBanamufullz+PBstrong],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [25.296974723359362, 19.721461572181433]
# [258.84622360098683, 191.28032096546875]
# [67.01295784946839, 57.265108200171134]

# %% [markdown]
# ## DESI Results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plot3/DESI/PB_base')
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plot3/DESI/PB_extrans')
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plot3/DESI/PB_extramn')
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plot3/DESI/PB_extraOk')
fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.3682618970599187]
# [115.69825787333407]
# [31.427521514587013]

# %% [markdown]
# fnlerrors([DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
# fnlerrors([DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
# fnlerrors([DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# print(1)
# fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
# fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
# fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# print(2)
# fnlerrors([DPBanamufullz],["fNLloc","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLloc"])
# fnlerrors([DPBanamufullz],["fNLeq","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLeq"])
# fnlerrors([DPBanamufullz],["fNLorth","lnAs", "h", "Om" ,"ob"]+biasindex,[ "fNLorth"])

# %% [markdown]
# ### Shotnoise and bias impact

# %%
getPlot([DPBanamufullzT,DPBanamufullz],["fNLeq","fNLorth"]+biasindex,["fNLeq","fNLorth"],["P+BTree","P +B"])
print(getError([DPBanamufullzT,DPBanamufullz],["fNLeq","fNLorth"]+biasindex,["fNLeq","fNLorth"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[115.93028158163725, 63.43820940954994], [127.51243733725116, 34.796601717081664]]

# %%
getPlot([DPanamufullz,DPanamufullzNS,DPBanamufullz,DPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plot3/DESI/shotnoise')
fnlerrors([DPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [1.6108800911882597]
# [70.78623503126776]
# [17.53481250891692]

# %%
samp1,cpar1,lb1 = getSamps([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plot3/DESI/biasfixns')

fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [1.9802121389956218]
# [21.1221106928382]
# [11.252446649605483]

# %% [markdown]
# ### 2 Loop P impact

# %%
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P +B","P 2L +B"],'plot3/DESI/PB_2L')
fnlerrors([DPBanamufullz2L],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz2L],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz2L],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.329076547234971]
# [117.28375299704665]
# [32.602533343478754]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([DPBanamufullzT,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plot3/DESI/PB_extrans_Tree')
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.456986254597712, 3.3640670320510258]
# [106.55262256233554, 120.48784343315758]
# [58.306660615555636, 32.87967501244351]

# %% [markdown]
# ### Fixed Bias

# %%
print(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.005433260378611356, 0.02352352813311134, 0.0033319742676279525, 0.01174776559927165], [0.0037573496151598954, 0.011626205203390987, 0.0017348937244949113, 0.004619304506557718]]
# Removed no burn in
# Removed no burn in
# [[0.006038828216327628, 0.03807818694578728, 0.00447030563209449, 0.02383570625922387], [0.004337233727482769, 0.02210299295084135, 0.0024267124237040633, 0.012409039401463741]]
# [2.036546464900119]
# [22.198532209055408]
# [11.922248179966262]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([DPanamufullz,DPanamufullz+DPstrong,DPBanamufullz,DPBanamufullz+DPBstrong],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P+Prior","P+B","P+B+Prior"],'plotwp/DESI/Priors')

fnlerrors([DPBanamufullz,DPBanamufullz+DPBstrong],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([DPBanamufullz,DPBanamufullz+DPBstrong],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([DPBanamufullz,DPBanamufullz+DPBstrong],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.3682618970599187, 3.2537418364131527]
# [115.69825787333407, 75.30296095251146]
# [31.427521514587013, 28.952629606659208]

# %% [markdown]
# ## MegaMapper optimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.2629185435848193]
# [17.752641208011365]
# [4.487432568826938]

# %%
fnlerrors([MMoPBanamufullzT],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzT],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzT],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.27392001240290204]
# [17.163339787536696]
# [7.747519567059541]

# %%
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plotsub/MMo/PB_base')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plotsub/MMo/PB_extrans')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plotsub/MMo/PB_extramn')
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plotsub/MMo/PB_extraOk')

fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2629185435848193]
# [17.752641208011365]
# [4.487432568826938]

# %% [markdown]
# ### Shot Noise impact and bias impact

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsub/MMo/shotnoise')
fnlerrors([MMoPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.09151428005432329]
# [4.340146180055342]
# [1.3320737484057181]

# %%
samp1,cpar1,lb1 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotsub/MMo/biasfixns')

fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.16315412424808814]
# [3.474110150175866]
# [1.6602935125745657]

# %%
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.00240779055855259, 0.007114317483210641, 0.0006606692726610165, 0.002292530748759163], [0.0012262206660271324, 0.0028461126329131464, 0.0001399860083783176, 0.0007956812592987146]]
# Removed no burn in
# Removed no burn in
# [[0.0036079760914276256, 0.014504648955088203, 0.0011096239881679007, 0.005632075292615073], [0.0021011841976324415, 0.005506552319264959, 0.000338593754555406, 0.002196109254716436]]
# [0.16315412424808814]
# [3.474110150175866]
# [1.6602935125745657]

# %%
fnlerrors([MMoPBanamufullzNS],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"],[ "fNLorth"])
# Out:
# [0.035654816669036436]
# [0.8086587090845867]
# [0.3948164182931198]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([MMoPBanamufullzT,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plotsub/MMo/PB_extrans_Tree')
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [0.27392001240290204, 0.2629185435848193]
# [17.163339787536696, 17.752641208011365]
# [7.747519567059541, 4.487432568826938]

# %%
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz],["fNLeq","fNLorth"]+biasindex,[ "fNLeq","fNLorth"])
getPlot([MMoPBanamufullzT,MMoPBanamufullz],["fNLeq","fNLorth"]+biasindex,["fNLeq","fNLorth"],["P+BTree","P +B"])
print(getError([MMoPBanamufullzT,MMoPBanamufullz],["fNLeq","fNLorth"]+biasindex,["fNLeq","fNLorth"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# [18.52546926421956, 18.140680208675082]
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[18.52546926421956, 8.362383859446286], [18.140680208675082, 4.5855193171341915]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([MMoPanamufullz,MMoPanamufullz+MMoPstrong,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P+Prior","P+B","P+B+Prior"],'plotwp/MMo/Priors')

fnlerrors([MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2654174286116948, 0.26392170088971745]
# [18.846528887101506, 15.02267095727902]
# [5.448555652616436, 4.364747748770167]

# %% [markdown]
# ## MegaMapper pesimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P","P +B"],'plotsub/MMp/PB_base')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P","P +B"],'plotsub/MMp/PB_extrans')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","mn", "ob"]+biasindex,[ "h", "lnAs","Om","mn"],["P","P +B"],'plotsub/MMp/PB_extramn')
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","Ok", "ob"]+biasindex,[ "h", "lnAs","Om","Ok"],["P","P +B"],'plotsub/MMp/PB_extraOk')

fnlerrors([MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.4257322238324965]
# [31.318044818892986]
# [8.048899084252238]

# %%
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [0.2629185435848193, 0.4257322238324965]
# [17.752641208011365, 31.318044818892986]
# [4.487432568826938, 8.048899084252238]

# %% [markdown]
# ### Shot Noise and bias impact

# %%
getPlot([MMpPanamufullz,MMpPanamufullzNS,MMpPBanamufullz,MMpPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plotsub/MMp/shotnoise')
fnlerrors([MMpPBanamufullzNS],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullzNS],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullzNS],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.1147726237455552]
# [6.358474594665775]
# [1.5250130280247243]

# %%
samp1,cpar1,lb1 = getSamps([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plotsub/MMp/biasfixns')

fnlerrors([MMpPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2893630858720153]
# [6.245072609227749]
# [3.020814763932028]

# %%
print(getError([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
print(getError([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
fnlerrors([MMpPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [[0.0032569732693169336, 0.010013102447470957, 0.0011517116339521542, 0.003820596123523192], [0.0020271320176128743, 0.004622520699212342, 0.00033744901481154037, 0.0012530139411010255]]
# Removed no burn in
# Removed no burn in
# [[0.003910953057683534, 0.01796574833407302, 0.0016707426211738006, 0.00826698964630397], [0.0030323069891509988, 0.008510347299850817, 0.0005844984838725579, 0.0036511499396715903]]
# [0.2893630858720153]
# [6.245072609227749]
# [3.020814763932028]

# %% [markdown]
# ### Tree Comparison

# %%
getPlot([MMpPBanamufullzT,MMpPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindex,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plotsub/MMp/PB_extrans_Tree')
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [0.4343031462329364, 0.4257322238324965]
# [29.682700919961796, 31.318044818892986]
# [13.791992043840068, 8.048899084252238]

# %% [markdown]
# # MMo vs MMpcomparison

# %%
getPlot([MMpPBanamufullz,MMoPBanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P +B MMp","P +B MMo"])
getPlot([MMpPanamufullz,MMoPanamufullz],["lnAs", "h", "Om" ,"ob"]+biasindex,[ "h", "lnAs","Om"],["P MMp","P MMo"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

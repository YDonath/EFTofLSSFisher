# %%
from resultsfuncs import *

# %%
Prioramb=mmread("../Fishers/Prioramb.mtx")

# %% [markdown]
# ### BOSS imports

# %% [markdown]
# Full P results w/o 4 sky correlation

# %%
Pfull4sky = mmread('../Fishers/BOSS/Pfull4sky.mtx')
Pfullnoskycorr = mmread('../Fishers/BOSS/Pfullnoskycorr.mtx')

# %% [markdown]
# Full PB cross w/o 4 sky correlation

# %%
PBcross4sky = mmread('../Fishers/BOSS/PBcross4sky.mtx')
PBcrossnoskycorr = mmread('../Fishers/BOSS/PBcrossnoskycorr.mtx')

# %% [markdown]
# Numerical covariance Diagonals  w/o 4 sky correlation,  w/o B

# %%
PNumD4sky = mmread('../Fishers/BOSS/PNumD4sky.mtx')
PNumDnoskycorr = mmread('../Fishers/BOSS/PNumDnoskycorr.mtx')
PBNumD4sky = mmread('../Fishers/BOSS/PBNumD4sky.mtx')
PBNumDnoskycorr = mmread('../Fishers/BOSS/PBNumDnoskycorr.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
Panafullz = mmread('../Fishers/BOSS/Panafullz.mtx')
PBanafullz = mmread('../Fishers/BOSS/PBanafullz.mtx')

PanafullznoAP = mmread('../Fishers/BOSS/PanafullznoAP.mtx')
PBanafullznoAP = mmread('../Fishers/BOSS/PBanafullznoAP.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B no shot noise (full mu)

# %%
PanamufullzNS = mmread('../Fishers/BOSS/PanamufullzNS.mtx')
PBanamufullzNS = mmread('../Fishers/BOSS/PBanamufullzNS.mtx')

# %% [markdown]
# Analytical covariance with full redshift dependence full mu dependence,  w/o B

# %%
Panamufullz = mmread('../Fishers/BOSS/Panamufullz.mtx')
PBanamufullz = mmread('../Fishers/BOSS/PBanamufullz.mtx')

# %% [markdown]
# Analytical covariance BTree

# %%
PBanamufullzT = mmread('../Fishers/BOSS/PBanamufullzT.mtx')

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
Pstrong = mmread('../Fishers/BOSS/Ppertprior.mtx')
PBstrong = mmread('../Fishers/BOSS/PBpertprior.mtx')

# %% [markdown]
# ### DESI Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
DPanafullz = mmread('../Fishers/DESI/Panafullz.mtx').real
DPBanafullz = mmread('../Fishers/DESI/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
DPanamufullz = mmread('../Fishers/DESI/Panamufullz.mtx').real
DPBanamufullz = mmread('../Fishers/DESI/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, 2loop,  w/o B

# %%
DPanamufullz2L = mmread('../Fishers/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('../Fishers/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B

# %%
DPBanamufullzT = mmread('../Fishers/DESI/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, NS,  w/o B

# %%
DPanamufullzNS = mmread('../Fishers/DESI/PanamufullzNS.mtx').real
DPBanamufullzNS = mmread('../Fishers/DESI/PBanamufullzNS.mtx').real

# %%
DPanamufullz2L = mmread('../Fishers/DESI/Panamufullz2L.mtx').real
DPBanamufullz2L = mmread('../Fishers/DESI/PBanamufullz2L.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
DPstrong = mmread('../Fishers/DESI/Ppertprior.mtx')
DPBstrong = mmread('../Fishers/DESI/PBpertprior.mtx')

# %% [markdown]
# ### MegaMapper -optimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMoPanafullz = mmread('../Fishers/MMo/Panafullz.mtx').real
MMoPBanafullz = mmread('../Fishers/MMo/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMoPanamufullz = mmread('../Fishers/MMo/Panamufullz.mtx').real
MMoPBanamufullz = mmread('../Fishers/MMo/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMoPBanamufullzT = mmread('../Fishers/MMo/PBanamufullzT.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  NS w/o B

# %%
MMoPanamufullzNS = mmread('../Fishers/MMo/PanamufullzNS.mtx').real
MMoPBanamufullzNS = mmread('../Fishers/MMo/PBanamufullzNS.mtx').real

# %%
MMoPanamufullz2L = mmread('../Fishers/MMo/Panamufullz2L.mtx').real
MMoPBanamufullz2L = mmread('../Fishers/MMo/PBanamufullz2L.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
MMoPstrong = mmread('../Fishers/MMo/Ppertprior.mtx')
MMoPBstrong = mmread('../Fishers/MMo/PBpertprior.mtx')

# %% [markdown]
# ### MegaMapper -pessimistic Imports

# %% [markdown]
# Analytical covariance with full redshift dependence,  w/o B

# %%
MMpPanafullz = mmread('../Fishers/MMp/Panafullz.mtx').real
MMpPBanafullz = mmread('../Fishers/MMp/PBanafullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles,  w/o B

# %%
MMpPanamufullz = mmread('../Fishers/MMp/Panamufullz.mtx').real
MMpPBanamufullz = mmread('../Fishers/MMp/PBanamufullz.mtx').real

# %% [markdown]
# Analytical covariance with full redshift dependence, all multipoles, Tree B w/o B

# %%
MMpPBanamufullzT = mmread('../Fishers/MMp/PBanamufullzT.mtx').real

# %% [markdown]
# Strong perturbative prior with bias scaling

# %%
MMpPstrong = mmread('../Fishers/MMp/Ppertprior.mtx')
MMpPBstrong = mmread('../Fishers/MMp/PBpertprior.mtx')

# %% [markdown]
# ## BOSS Pipeline validation

# %% [markdown]
# Reduction to Diagonal Covariance and fits

# %%
getPlot([Pfull4sky,PNumDnoskycorr,Panafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["P measured Covariance","P NumD","P Analytical"])
getPlot([PBcross4sky,PBNumDnoskycorr,PBanafullz],["lnAs", "h", "Om", "ob"]+biasindex,[ "h", "lnAs","Om"],["$P_\ell+B_0$ measured Cov.","$P_\ell+B_0$ measured diagonal Cov.","$P_\ell+B_0$ analytical diagonal Cov."],'plots/BOSS/PB_Diagvalidation',15, 15, 15)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %%
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLloc"]+biasindex,[ "fNLloc"])
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLeq"]+biasindex,[ "fNLeq"])
fnlerrors([PBcross4sky,PBNumDnoskycorr,PBanafullz],["fNLorth"]+biasindex,[ "fNLorth"])
# Out:
# [41.781239755178255, 29.327467034059797, 27.924580221990126]
# [357.02468647935353, 314.049918131981, 274.5081001160121]
# [100.3991136267302, 111.16172027515522, 94.55827556760183]

# %% [markdown]
# ## BOSS Results

# %% [markdown]
# ### Additional Parameters, with full numerical covariances

# %%
getPlot([Pfullnoskycorr,PBcrossnoskycorr],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["$P_\ell$","$P_\ell+B_0$"],'plots/BOSS/PBNum_extrans',30,18,24)
getPlot([Pfullnoskycorr,PBcrossnoskycorr],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["$P_\ell$","$P_\ell+B_0$"],'plots/BOSS/PBNum_extramn',24, 15, 20,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.08941232068215355, 0.8444940387591933], [-0.08034095186936346, 0.40867162710772625]]

# %%
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBcrossnoskycorr,PBNumDnoskycorr,PBanafullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# [35.781916172449186, 26.678295942902956, 25.207536762137476]
# [245.20866202094174, 300.52816478624123, 265.69366533268584]
# [93.61151366077878, 111.14961672913454, 94.38745254460497]

# %% [markdown]
# ### Impact of higher multipoles and shot noise (with analytical covariance)

# %%
fnlerrors([PBanafullznoAP,PBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanafullznoAP ,PBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanafullznoAP,PBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# [25.207536762146265, 23.01438488309409]
# [265.693665332619, 252.7372410358431]
# [94.38745254457704, 67.09341816962367]

# %%
getPlot([PanafullznoAP,Panamufullz,PBanafullznoAP,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["$P_0+P_2$","$P^r$ full","$P_0+P_2+B_0$","$P^r+B^r$ full"],'plots/BOSS/highermulti',20, 15, 20)
getPlot([Panamufullz,PanamufullzNS,PBanamufullz,PBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plots/BOSS/shotnoise',20, 15, 20)
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanafullz,PBanamufullz,PBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [25.207536762137476, 23.01438488309409, 11.164539947248581]
# [265.69366533268584, 252.7372410358431, 147.35572830135362]
# [94.38745254460497, 67.09341816962367, 40.688692498899755]

# %%
samp1,cpar1,lb1 = getSamps([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([Panamufullz,PBanamufullz,Panamufullz+Prioramb,PBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P","P+B","P+g.p.","P+B+g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plots/BOSS/biasfixns',16, 15, 20)

fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanamufullz,PBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([PBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([PBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([PBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [23.01438488309409, 19.30700081133056]
# [252.7372410358431, 187.21646766269268]
# [67.09341816962367, 51.42096414236866]
# [4.779712287194547]
# [45.49163329498812]
# [26.295086635523607]

# %%
printerr(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))

printerr(getError([Panamufullz+Prioramb,PBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))

printerr(getError([Panamufullz,PBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.01395  0.161    0.01242  0.06747 ]
#  [0.006669 0.05451  0.005714 0.0253  ]]
# Removed no burn in
# Removed no burn in
# [[0.01308  0.1317   0.0107   0.04709 ]
#  [0.006503 0.04312  0.004881 0.01918 ]]
# Removed no burn in
# Removed no burn in
# [[0.0122   0.05646  0.007778 0.02606 ]
#  [0.00536  0.01916  0.003518 0.007465]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/BOSS/fnlwithbiasT',18, 15, 20)

fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([PBanamufullzT,PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [37.40697165467831, 23.01438488309409, 17.47812841336778, 15.103659163666084]
# [357.1956966069592, 252.7372410358431, 228.1699856769975, 163.93031232122306]
# [142.16733084388113, 67.09341816962367, 62.43441608155911, 49.105577375885844]

# %%
getPlot([PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/BOSS/PB_extrans_prior',25,18,24)
getPlot([PBanamufullz,PBanamufullz+PBstrong,PBanamufullz+PBstrong+Prioramb],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/BOSS/PB_extramn_prior',18, 15, 20,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.07132180553526138, 0.2486969869144145], [-0.07054238095928031, 0.23947074901664162], [-0.06599792580869093, 0.19409970532197707]]

# %% [markdown]
# ## DESI Results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["P","P +B"],'plots/DESI/PB_extrans',30,18,24)
getPlot([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plots/DESI/PB_extramn',24, 15, 20,1)
fnlerrors([DPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.0724009443300388, 0.262331237691005], [-0.0465507651807442, 0.08709341740468408]]
# [3.456694796994808]
# [114.25109544173044]
# [30.187470134808535]

# %% [markdown]
# ### Shotnoise and bias impact

# %%
getPlot([DPanamufullz,DPanamufullzNS,DPBanamufullz,DPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plots/DESI/shotnoise',20, 15, 20)
fnlerrors([DPBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [1.6717581220785622]
# [67.32399783409096]
# [17.294727879207922]

# %%
samp1,cpar1,lb1 = getSamps([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([DPanamufullz,DPBanamufullz,DPanamufullz+Prioramb,DPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P","P+B","P+g.p.","P+B+g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plots/DESI/biasfixns',16, 15, 20)

fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz,DPBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([DPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([DPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([DPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.456694796994808, 3.3551337341965097]
# [114.25109544173044, 83.3985632930665]
# [30.187470134808535, 22.931829960285633]
# [1.988483619288975]
# [20.73871273887992]
# [11.05455275135834]

# %%
printerr(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([DPanamufullz+Prioramb,DPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([DPanamufullz,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.005742 0.0355   0.00409  0.01879 ]
#  [0.00424  0.01952  0.00221  0.01049 ]]
# Removed no burn in
# Removed no burn in
# [[0.005648 0.03216  0.004049 0.01555 ]
#  [0.004194 0.01763  0.002156 0.009034]]
# Removed no burn in
# Removed no burn in
# [[0.005314 0.0213   0.003211 0.01084 ]
#  [0.003726 0.01045  0.001583 0.004074]]

# %% [markdown]
# ### 2 Loop P impact

# %%
getPlot([DPBanamufullz,DPBanamufullz2L],["lnAs", "h", "Om" ,"ob"]+biasindexstfix,[ "h", "lnAs","Om"],["P +B","P 2L +B"],'plots/DESI/PB_2L',20, 15, 20)
fnlerrors([DPBanamufullz2L],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullz2L],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullz2L],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.4227338386477397]
# [111.8765876911343]
# [30.11726636905527]

# %% [markdown]
# ### Tree comparison

# %%
getPlot([DPBanamufullzT,DPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P+BTree","P +B"],'plots/DESI/PB_extrans_Tree',20, 15, 20)
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# [3.6094664022749523, 3.456694796994808]
# [141.67776536199747, 114.25109544173044]
# [71.54468968139815, 30.187470134808535]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/DESI/fnlwithbiasT',18, 15, 20)

fnlerrors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([DPBanamufullzT,DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [3.6094664022749523, 3.456694796994808, 3.26842640347893, 3.1882790567647503]
# [141.67776536199747, 114.25109544173044, 91.5053803667967, 76.99869476876756]
# [71.54468968139815, 30.187470134808535, 26.983228543019415, 21.814437333326662]

# %%
getPlot([DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/DESI/PB_extrans_prior',25,18,24)
getPlot([DPBanamufullz,DPBanamufullz+DPBstrong,DPBanamufullz+DPBstrong+Prioramb],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/DESI/PB_extramn_prior',18,15, 20,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.0465507651807442, 0.08709341740468408], [-0.0456671393019086, 0.08405068077616017], [-0.04392877155372432, 0.0783445855762094]]

# %% [markdown]
# ## MegaMapper optimistic results

# %% [markdown]
# ### Base Results (All multipoles)

# %%
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P","P +B"],'plots/MMo/PB_extrans',30,18,24)
getPlot([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plots/MMo/PB_extramn',24, 15, 20,1)
fnlerrors([MMoPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.031474173327359634, 0.04593038107765875], [-0.007931784351379992, 0.008615116840812662]]
# [0.2659878703708509]
# [17.69637934803105]
# [4.618035205331568]

# %%
getPlot([MMoPBanamufullz,MMoPBanamufullz2L],["lnAs", "h", "Om","ns", "Ok","ob"]+biasindexstfix,[ "h", "lnAs","Om","ns", "Ok"],["P","P +B"],'plots/MMo/PB_extrans2L',30,18,24)
# Out:
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### Shot Noise impact and bias impact

# %%
getPlot([MMoPanamufullz,MMoPanamufullzNS,MMoPBanamufullz,MMoPBanamufullzNS],["lnAs", "h","ns", "Om", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P",r"P: $n_b \rightarrow\infty$","P+B",r"P+B: $n_b \rightarrow\infty$"],'plots/MMo/shotnoise',20, 15, 20)
fnlerrors([MMoPBanamufullzNS],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullzNS],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullzNS],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.11042541228301266]
# [5.438386235976574]
# [1.5319590702998074]

# %%
samp1,cpar1,lb1 = getSamps([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"])
samp2,cpar2,lb2 = getSamps([MMoPanamufullz,MMoPBanamufullz,MMoPanamufullz+Prioramb,MMoPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P","P+B","P+g.p.","P+B+g.p."])
getPlotfromSamps(combinesamps([samp2,samp1]),cpar1,sum([lb2,lb1], []),'plots/MMo/biasfixns',16, 15, 20)


fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullz,MMoPBanamufullz+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
fnlerrors([MMoPBanamufullz],["fNLloc"],[ "fNLloc"])
fnlerrors([MMoPBanamufullz],["fNLeq"],[ "fNLeq"])
fnlerrors([MMoPBanamufullz],["fNLorth"],[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2659878703708509, 0.26236412332115744]
# [17.69637934803105, 13.263085782401463]
# [4.618035205331568, 3.5604619164960716]
# [0.17076807326494972]
# [3.613618519783906]
# [1.7392791445722053]

# %%
printerr(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([MMoPanamufullz+Prioramb,MMoPBanamufullz+Prioramb],["lnAs", "h", "Om","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns"],["P: bias free","P+B: bias free"]))
printerr(getError([MMoPanamufullz,MMoPBanamufullz],["lnAs", "h", "Om","ns", "ob"],[ "h", "lnAs","Om","ns"],["P: bias fixed","P+B: bias fixed"]))
# Out:
# Removed no burn in
# Removed no burn in
# [[0.003598  0.0132    0.001161  0.005029 ]
#  [0.002051  0.004723  0.0003393 0.00174  ]]
# Removed no burn in
# Removed no burn in
# [[0.00344   0.01066   0.001097  0.004253 ]
#  [0.002     0.004543  0.0003257 0.001642 ]]
# Removed no burn in
# Removed no burn in
# [[0.002857  0.007363  0.0007855 0.002442 ]
#  [0.001643  0.003432  0.0002076 0.0009572]]

# %% [markdown]
# ### Perturbative Prior

# %%
getPlot([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMo/fnlwithbiasT',18, 15, 20)

fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMoPBanamufullzT,MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.2859617706366799, 0.2659878703708509, 0.2609588042189095, 0.25622495922412186]
# [23.405074574321276, 17.69637934803105, 16.03585830270241, 12.593790066030348]
# [8.68922563072317, 4.618035205331568, 4.200012364788656, 3.4269557669480557]

# %%
getPlot([MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMo/PB_extrans_prior',25,18,24)
getPlot([MMoPBanamufullz,MMoPBanamufullz+MMoPBstrong,MMoPBanamufullz+MMoPBstrong+Prioramb],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMo/PB_extramn_prior',18, 15, 20,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.007931784351379992, 0.008615116840812662], [-0.007465008742367912, 0.008067228019273426], [-0.007180860066565362, 0.007736400134406671]]

# %% [markdown]
# ## MegaMapper pesimistic results
#
# ### Base Results (All multipoles)

# %%
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","Ok","ns", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],["P","P +B"],'plots/MMp/PB_extrans',30,18,24)
getPlot([MMpPanamufullz,MMpPBanamufullz],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],["P","P +B"],'plots/MMp/PB_extramn',24, 15, 20,1)

fnlerrors([MMpPBanamufullz],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMpPBanamufullz],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMpPBanamufullz],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.04557996290075706, 0.08375584679891947], [-0.013419740136915437, 0.015499768836611263]]
# [0.4397140280030436]
# [32.92224600823819]
# [8.489671082995217]

# %% [markdown]
# ### Perturbative prior

# %%
getPlot([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq","logb1","c2","c4"],['$P+B_{Tree}$','$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMp/fnlwithbiasT',18, 15, 20)

fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLloc"]+biasindexstfix,[ "fNLloc"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLeq"]+biasindexstfix,[ "fNLeq"])
fnlerrors([MMpPBanamufullzT,MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["fNLorth"]+biasindexstfix,[ "fNLorth"])
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [0.4513428709581922, 0.4397140280030436, 0.4225986244771454, 0.41742557757663357]
# [40.80626736601931, 32.92224600823819, 29.50236639189487, 22.994819433541924]
# [18.077313139655345, 8.489671082995217, 7.979769917409281, 6.486761329064154]

# %%
getPlot([MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["lnAs", "h", "Om","ns","Ok", "ob"]+biasindexstfix,[ "h", "lnAs","Om","ns","Ok"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMp/PB_extrans_prior',20, 15, 20)
getPlot([MMpPBanamufullz,MMpPBanamufullz+MMpPBstrong,MMpPBanamufullz+MMpPBstrong+Prioramb],["lnAs", "h", "Om","logmn", "ob"]+biasindexstfix,[ "h", "lnAs","Om","logmn"],['$P+B$','$P+B+pert. Prior$','$P+B+pert. Prior+ g.p$'],'plots/MMp/PB_extramn_prior',18, 15, 20,1)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [[-0.013419740136915437, 0.015499768836611263], [-0.012647252979358273, 0.01447836892452814], [-0.012111627140117695, 0.013780693334062386]]
